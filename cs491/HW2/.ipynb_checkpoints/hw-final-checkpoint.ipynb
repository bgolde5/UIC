# %%
import re

# loop through each class and see if they are similar
def entity_resolution_between_list(classes_list, distance_constant=5):
    #fold list of lists into one list
    classes = [item for sublist in classes_list for item in sublist]
    distinct_classes = {}
    for i in range(0, len(classes)):
        a_class = classes[i].replace('\n', '')
        a_class = a_class.lower()
        for j in range(i, len(classes)):
            if i == j:
                pass
            elif edit_distance(a_class, classes[j].lower()) <= distance_constant:
                try:
                    distinct_classes[a_class] = True
                except KeyError:
                    distinct_classes.append({a_class, True})
                    
    print(len(distinct_classes))
    return distinct_classes;

def edit_distance(word1, word2):
    """This algorithm involves looping through word1 and converting it to word2 letter by letter,
    replacing/deleting/inserting each character that doesn't match exactly."""
    
    if len(word1) == 0:
        return 0
    if len(word2) == 0:
        return 0
    
    word1 = list(word1.lower())
    word2 = list(word2.lower())
    
    distance = 0
    
    # find the shortest word
    shortest_word_len = 0
    if len(word1) < len(word2):
        shortest_word_len = len(word1)
    else:
        shortest_word_len = len(word2)
        
    # find the longest word
    longest_word_len = 0
    if len(word1) > len(word2):
        longest_word_len = len(word1)
    else:
        longest_word_len = len(word2)
    
    # loop for the duration of the shortest word
    # ensures there is no insertion at this point
    # strictly deletion and replacing
#     print("".join(word1), "".join(word2))
    for i in range(0, shortest_word_len):
        
        # letters are the same
        if word1[i] == word2[i]:
            pass
        
        # letters are not the same
        elif word1[i] != word2[i]:
            word1[i] = word2[i]
#             print("".join(word1), "".join(word2))
            distance += 1
    
    # loop through any remaining characters
    # that are empty strings and replace / delete them
    for i in range(shortest_word_len, longest_word_len):
        # if word2 no longer has letters, than word1 is longer
        # deletion is needed
        if i >= shortest_word_len and len(word1) > len(word2):
            word1.pop()
            distance += 1
#             print("".join(word1), "".join(word2))
            continue
        
        # if letters don't exist in word1 that are in word2
        # insertion is needed
        try:
            word1.append(word2[i])
#             print("".join(word1), "".join(word2))
            distance += 1
            continue
        except:
            pass

    return distance

def remove_punctuation(word):
    remove_punc_pattern = r'\w*'
    return re.match(remove_punc_pattern, word).group(0)

def get_name(unknown_name_format):
    
    name_dict = {}
    pattern = None
    
    # format is firstname.lastname
    if len(unknown_name_format.split('.')) == 2 and len(unknown_name_format.split(' ')) == 1:
        first_name, last_name = unknown_name_format.split('.')
        return {'last_name':last_name.capitalize(), 'first_name':first_name.capitalize()}
        
    # one word in name
    elif len(unknown_name_format.split(' ')) == 1:
        return {'last_name':remove_punctuation(unknown_name_format).capitalize()}
    
    # if comma after first word
    elif unknown_name_format.split(" ")[0][-1] == ',':
        pattern = re.compile(r"(?P<last_name>\w+,)\s(((?P<middle_initial>\w+.|\w+)\s)|\b)((?P<first_name>\w+))|\b")
        
    else:
        pattern = re.compile(r"(?P<first_name>\w+(.|\b))\s*(((?P<middle_initial>\w+|\w+.)\s)|\b)(?P<last_name>\w*)")
    
    reg = re.match(pattern, unknown_name_format)

    if reg.group('first_name'):
        name_dict['first_name'] = remove_punctuation(reg.group('first_name')).capitalize()

    if reg.group('middle_initial'):
        name_dict['middle_initial'] = remove_punctuation(reg.group('middle_initial')).capitalize()

    if reg.group('last_name'):
        name_dict['last_name'] = remove_punctuation(reg.group('last_name')).capitalize()
    
    return name_dict;

def separate_classes_into_list(classes):
    return re.split("\|", classes)

def separate_name_from_classes(row):
    row = row.split("  - ")
    return row[0], row[1]

# def append_name_to_each_cclass(name, classes):

def import_csv(filename):
    with open('class.txt') as csvfile:
        data = {}
        classes_list = []
        for row in csvfile:
            name, classes = separate_name_from_classes(row)
            classes = separate_classes_into_list(classes)
            classes_list.append(classes)
            name = get_name(name)
            
            # oraganize all classes by last name
            # of professor who teaches them
            for a_class in classes:
                a_class = a_class.replace('\n', '')
                try:
                    data[name['last_name']] = a_class
                except KeyError:
                    data.append({name['last_name'],a_class})
#         print(classes_list)
        print(entity_resolution_between_list(classes_list, 5))
    # TODO - see which classes are being resolved and chech that there are no errors
        return data

print(import_csv('class.txt'))
# Out:
# 51
# {'temporalitiez': True, 'intro. to computer graphicz': True, 'advanced programming for digital art and literature': True, 'the literary scholar': True, 'introductory compiler construction': True, 'computer aided visualization and design': True, 'fundamentals of computer systems': True, 'data-driven vision and graphics': True, 'altered states': True, 'database management systems': True, 'topics in ecology and evolutionary biology': True, 'art after india': True, 'transport and biotransport processes': True, 'introductory calculus, part ii': True, 'biomaterials': True, 'recent applications of probability & statistics': True, 'writing and speaking chineze i': True, 'probabilistic graphical models': True, 'special topicz in advanced algorithms': True, 'nineteenth-century british novel': True, 'the postcolonial and the postmodern': True, 'analytic geometry & calculus': True, 'introductory calculuz, part ii': True, 'computational theory of molecular evolution': True, 'reinventions of life: aesthetics, biopolitics, and the avant-gardes': True, 'cell & molecular biology': True, 'fracture mechanics': True, 'parallel computation: models, algorithms, limits': True, 'melville, conrad, & the sea': True, 'computer vizion': True, 'quantum mechanics': True, 'data-driven vizion and graphics': True, 'hilbert spaces & their applications': True, 'interdisciplinary scientific visualization': True, 'molecular genetics': True, 'intro. to computation for the humanities and social sciences': True, 'distributed computing through combinatorial topology': True, 'narrative and immersion': True, 'intro. to power engineering': True, 'filtering and prediction of hidden markov models': True, 'foundationz of electromagnetism and modern physics': True, 'american fiction & mass culture': True, 'foundations of electromagnetism and modern physics': True, 'intro to combinatorial optimization': True, 'introductory calculus, part i': True, 'principles of ecology': True, 'reinventionz of life: aesthetics, biopolitics, and the avant-gardes': True, 'intro. to computation for the humanities & social sciences': True, '3d photography & geometry processing': True, 'computational methodz for biology': True, 'mechanics of solids': True}
# {'Solworth': 'Intro. to Computation for the Humanities and Social Sciences', 'Ziebart': 'Intro. to Number Theory', 'Caliskan': 'Statistical Mechanics', 'Soheili': 'Biophysical and Bioinorganic Chemistry', 'Sistla': 'Algorithmic Foundations of Computational Biology', 'Checkoway': 'Intro to Combinatorial Optimization', 'Gallik': 'Intro. to Computer Graphicz', 'Savar': 'Intellectual Life & Culture in the Post-Western World', 'Rao': 'Touring the Empire: Travel Literature and the Idea of America', 'Marai': 'Temporalitiez', 'Ozevin': 'Fundamentals of Computer Systems', 'Jones': 'Filtering and Prediction of Hidden Markov Models', 'Velebit': 'Advanced Programming for Digital Art and Literature', 'Ansari': 'American Fiction and Mass Culture', 'Dunn': 'introduction to architectural design', 'Clarno': 'Intro. to Computation for the Humanities & Social Sciences', 'Zuck': 'Basic Physics', 'Jin': 'Advanced Algorithms Seminar', 'Brennan': 'Astrophysics and Cosmology', 'Vinella': 'Intro to Combinatorial Optimization', 'Taylor': 'The Aesthetics of Color: History, Theory, Critique', 'Metlushko': 'Melville, Conrad, and the Sea', 'Troy': 'Introductory Compiler Construction', 'Reddy': 'Quantum Mechanics', 'Dai': 'introductory calculus, part ii', 'Gillet': 'Quantum Mechanics', 'Boy': 'Narrative and Immersion', 'Valbonesi': 'computer vizion', 'Archias': 'Intro. to Modernism: Past, Future, Exile, Home', 'Foster': 'Analytic Geometry & Calculus', 'Vamanan': 'Dynamics and Vibrations', 'Fink': 'The Public Intellectual', 'Bergerwolf': 'Computational Methodz for Biology', 'Sinapova': 'The Claims of Fiction', 'Lekili': 'Filtering & Prediction of Hidden Markov Models', 'Wolfson': 'Database Management Systems', 'Bassiri': 'Heat and Mass Transfer', 'Cui': 'Computational Theory of Molecular Evolution', 'Cranch': '3D Photography & Geometry Processing', 'Bailey': 'operating systems', 'Furman': 'Art After India', 'Yu': 'Computers and Human Values', 'Hogan': 'Interdisciplinary Scientific Visualization', 'Wolak': 'American Fiction & Mass Culture', 'Tafti': 'Advanced Programming for Digital Art & Literature', 'Chudnovsky': 'Topics in Grounded Language for Robotics', 'Reed': 'Introduction to Discrete Structures & Probability', 'Eriksson': 'Computer Graphics Lab', 'Adiutori': 'American Fiction & Mass Culture', 'Kenyon': 'Human Factors & User Interface Design', 'Kanich': 'Accelerated Introduction to Computer Science', 'Walden': 'Interdisciplinary Scientific Visualization', 'Sauerwald': 'Writing and Speaking Chinese I', 'Theys': 'Distributed Computing through Combinatorial Topology', 'Lu': 'Temporalities', 'Kshemkalyani': 'Introductory Calculus, Part I', 'Mojab': 'Individual Independent Study', 'Westland': 'Introductory Calculuz, Part II', 'Fish': 'Intro. to Computer Graphicz', 'Bell': 'Art After India', 'Forbes': 'Introductory Biochemistry', 'Johnson': 'Computer Aided Visualization and Design', 'Lillis': 'Advanced Programming for Digital Art and Literature', 'Dasgupta': 'cultures & countercultures: the american novel after world war ii', 'Lyons': 'Internet and Web Algorithms', 'Shonfeld': 'Medical Bioinformatics', 'Barbara': 'Fracture Mechanics', 'Gmytrasiewicz': 'Fundamentals of Computer Systems', 'Krall': 'The Postcolonial and the Postmodern', 'Hummel': 'Introductory Compiler Construction', 'Siber': 'Cell & Molecular Biology', 'Sloan': 'introduction to computational linguistics'}
